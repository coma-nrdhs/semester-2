# %% [markdown]
# <a href="https://colab.research.google.com/github/coma-nrdhs/semester-2/blob/main/Stack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
items = np.zeros(size)

# %%
class stack:
  def __init__(self, size):
    self.top = -1

# %%
def push (my_stack,e):
  if my_stack.top == size - 1:
    print('overflow')
  else:
    my_stack.top = my_stack.top + 1
    items[my_stack.top] = e

# %%
def pop (my_stack):
  if my_stack.top ==  - 1:
    print('underflow')
  else:
    e = items[my_stack.top]
    my_stack.top = my_stack.top - 1
    return e

# %%
def print_stack(my_stack):
  if my_stack.top == -1:
    print('empty')
  else:
    i = my_stack.top
    while i > -1:
      print(items[i])
      i = i - 1

# %%
a_stack = stack(100)

# %%
element = int(input('Enter a number'))
push( a_stack,element)

element = int(input('Enter a number'))
push( a_stack,element)

element = int(input('Enter a number'))
push( a_stack,element)
# Out:
# Enter a number1
# Enter a number3
# Enter a number5

# %%
print_stack(a_stack)
print(a_stack.top)
# Out:
# 5.0
# 3.0
# 1.0
# 2

# %%
print(pop(a_stack))
# Out:
# underflow
# None
