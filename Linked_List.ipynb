# %% [markdown]
# <a href="https://colab.research.google.com/github/coma-nrdhs/semester-2/blob/main/Linked_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# List Definition

# %%
class Node:
  def __init__(self, my_data):
    self.data = my_data
    self.next = None

# %%
class Linked_List:
  def __init__(self):
    self.head = None

# %%
def insert_front(my_list, my_data) :
    new_node =Node(my_data)
    new_node.next = my_list.head
    my_list.head = new_node

# %%
def insert_rear(my_list, my_data) :
    new_node =Node(my_data)
    my_link = my_list.head
    if my_link == None:
      my_list.head = new_node
    else:

      while (my_link != None) :
       if my_link.next == None:
         my_link.next = new_node
         break
       my_link = my_link.next

# %%
 def print_list(my_list) :
    my_link = my_list.head
    while (my_link != None) :
      print(my_link.data)
      my_link = my_link.next

# %%
def search_list(my_list, value):
   my_link = my_list.head
   i = 0
   while (my_link != None) :
      if my_link.data == value:
        return i
      my_link = my_link.next
      i = i + 1
   else :
      return -1

# %% [markdown]
# Insert into front of Linked List

# %%
lList = Linked_List()
i = 0
while i < 5 :
  my_data = int(input("Enter Number: "))
  insert_front(lList, my_data)
  i = i + 1
# Out:
# Enter Number: 10
# Enter Number: 20

# %% [markdown]
# Insert into rear(end) of Linked List

# %%
lList = Linked_List()
i = 0
while i < 5 :
  my_data = int(input("Enter Number: "))
  insert_rear(lList, my_data)
  i = i + 1
# Out:
# Enter Number: 10
# Enter Number: 20
# Enter Number: 30
# Enter Number: 40
# Enter Number: 50

# %%
print_list(lList)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
search_list(lList, 30)
# Out:
# 2

# %% [markdown]
# End Here

# %%
class LinkedList:
  def __init__(self):
    self.head = None

  def insert_front(self, new_data) :
    new_node =Node(my_data)
    new_node.next = self.head
    self.head = new_node
  def print_list(self) :
    my_link = self.head
    while (my_link != None) :
      print(my_link.data)
      my_link = my_link.next

# %%
lList = LinkedList()

# %%
i = 0
while i < 5 :
 my_data = int(input("Enter Number: "))
 lList.insert_front(my_data)
 i = i+ 1
# Out:
# Enter Number: 10
# Enter Number: 10
# Enter Number: 30
# Enter Number: 40
# Enter Number: 50

# %%
lList.insert_front(my_data)

# %%
lList.print_list()
# Out:
# 50
# 40
# 30
# 10
# 10

# %%
#i = 0
#while i < 5 :


#my_node = Node(my_data)

 #New_Node.next = lList.head
 #lList.head = New_Node
 #i = i + 1
# Out:
# Enter Number: 10
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipython-input-3978735860.py in <cell line: 0>()
#       4
#       5 #my_node = Node(my_data)
# ----> 6 lList.insert_front(my_data)
#       7  #New_Node.next = lList.head
#       8  #lList.head = New_Node
#
# /tmp/ipython-input-638488652.py in insert_front(self, new_node)
#       4   def insert_front(self,new_node) :
#       5     #new_node =Node(my_data)
# ----> 6     new_node.next = head
#       7     head = new_node.next
#
# UnboundLocalError: cannot access local variable 'head' where it is not associated with a value

# %%
my_link = lList.head
while (my_link != None) :
  print(my_link.data)
  my_link = my_link.next
# Out:
# 7
# 8
# 9
# 10
# 11
# 11
